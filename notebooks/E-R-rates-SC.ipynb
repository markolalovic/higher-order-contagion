# %% [markdown]
# ## Erdos-Renyi SC Rates

# %%
import numpy as np
import matplotlib.pylab as plt
import random
from scipy.special import comb

import sys
sys.path.append('../src/')
from Hypergraphs import EmptyHypergraph
from simulate_gillespie import *
from estimate_total_rates import *

sys.path.append('../scripts/')
from generators_sc import p1_p2_ER_like_simplicial_complex, ER_like_simplicial_complex

# %% [markdown]
# ## Setup

# %%
## --- Setup --- ##
test_name = "random_ER"
g_type = "random_ER"

N = 1000
I0 = 1
nsims = 500
run_gillespie_simulations = True
time_max = 50

max_pw_edges = comb(N, 2, exact=True) # N * (N - 1) / 2
max_ho_edges = comb(N, 3, exact=True) # N * (N - 1) * (N - 2) / 6

k1_k2_list = [(3, 1), (6, 2), (10, 3), (20, 6)]
(k1, k2) = k1_k2_list[2]

p1, p2 = p1_p2_ER_like_simplicial_complex(k1,k2,N)
print(f"target p1: {p1:.4f}")
print(f"target p2: {p2:.8f}\n")
print(f"target pw edges: {p1 * max_pw_edges:.0f}/{max_pw_edges:.0f}")
print(f"target ho edges: {p2 * max_ho_edges:.0f}/{max_ho_edges:.0f}\n")


G, edges, triangles = ER_like_simplicial_complex(N,p1,p2)
all_edges = edges.tolist() + triangles.tolist()
g_edges = []
for edge in all_edges:
    g_edges.append(tuple(edge))

g = EmptyHypergraph(N)
g.name = "ER_SC"
g.set_edges(g_edges)

p1_est = len(edges) / max_pw_edges
p2_est = len(triangles) / max_ho_edges
print(f"realized p1: {p1_est:.4f}")
print(f"realized p2: {p2_est:.8f}\n")
print(f"realized pw edges:  {len(edges):.0f}/{max_pw_edges:.0f}")
print(f"realized ho edges:  {len(triangles):.0f}/{max_ho_edges:.0f}\n")

# set beta1, beta2 such that k^* = .75 N
mu    = 1             # recovery rate

# lambda_1 \in [0,3]
# lambda_2 \in [0,10]
lambda1 = 1.1
lambda2 = 5.0

beta1 = lambda1 * mu / k1 # pairwise infection rate
beta2 = lambda2 * mu / k2 # hyperedge contagion rate

# g.summary()

print(f"{test_name}: \n")
print(f"\tH = {g.name}, N = {N}, (k1, k2) = {(k1, k2)}, I0 = {I0}, time_max = {time_max},")
g.print()

print(f"\tbeta1 * N = {beta1 * N:.2f}, beta2 * N^2 = {beta2 * (N**2):.2f}, mu = {mu},")
print(f"\twith estimation based on {nsims} Gillespie simulation runs\n")
# Out:
# target p1: 0.0040
# target p2: 0.00000602
#
# target pw edges: 2012/499500
# target ho edges: 1000/166167000
#
# not connected, but GC has order  977 and size 1972
# realized p1: 0.0095
# realized p2: 0.00000557
#
# realized pw edges:  4729/499500
# realized ho edges:  925/166167000
#
# random_ER:
#
# 	H = ER_SC, N = 1000, (k1, k2) = (10, 3), I0 = 1, time_max = 50,
# 	ER_SC on 1000 nodes with 5654 edges.
#
# 	beta1 * N = 110.00, beta2 * N^2 = 1666666.67, mu = 1,
# 	with estimation based on 500 Gillespie simulation runs

# %% [markdown]
# ## Run Gillespie

# %%
## --- Run Gillespie ---
run_gillespie_simulations = False

I0_gillespie = I0 # TODO: go over the range when necessary
nodes = list(g.nodes.keys())
initial_infections = random.sample(nodes, I0)

if run_gillespie_simulations: 
    X_sims = []
    for _ in range(nsims):
        X_t = gillespie_sim(g, beta1, beta2, mu, initial_infections, time_max)
        X_sims.append(X_t)

    # save the simulation results
    sim_results = {f'sim_{i}': X_sims[i] for i in range(nsims)}
    np.savez_compressed(f'../results/gillespie-sims_{test_name}_SC.npz', **sim_results)
else: 
    # load simulation results
    sim_results = np.load(f'../results/gillespie-sims_{test_name}_SC.npz', allow_pickle=True)
    X_sims = [sim_results[f'sim_{i}'] for i in range(nsims)]

# plot X_t curves in gray and average curve in red
fig = plt.figure(dpi=150) # set DPI
ax  = plt.subplot()

for X_t in X_sims:
    ax.plot(X_t[0], X_t[2], c="blue", alpha=0.9, linewidth=0.5, rasterized=True)

plt.axhline(y=int(0.75 * N), color='black', lw=2, alpha=0.4, linestyle='-')

plt.xlabel("Time")
plt.ylabel("Number of Infected")
plt.grid(True)
plt.title(f"H = {g.name}, N = {N}, I0 = {I0}, nsims = {nsims}")
plt.savefig(f"../figures/estimation/{test_name}/gillespie-sims_SC.pdf", 
            format='pdf', bbox_inches='tight')
plt.show()
plt.close(fig) # free up memory
# Out:
# break: total_infected == 0: 0, time=0.9645057924213154
# exited on time=50.0021454134592, waiting_time=0.003645245434029911
# exited on time=50.000696510606886, waiting_time=0.0015800595638184756
# break: total_infected == 0: 0, time=0.319428184028551
# break: total_infected == 0: 0, time=0.7564967213126733
# exited on time=50.00015568032611, waiting_time=0.0009063001711167918
# break: total_infected == 0: 0, time=0.6577676963278949
# exited on time=50.001616945129626, waiting_time=0.0019883984383261897
# break: total_infected == 0: 0, time=1.637423175995743
# break: total_infected == 0: 0, time=0.3044848698362952
# exited on time=50.000007449824395, waiting_time=0.00026633598711386285
# break: total_infected == 0: 0, time=0.21059622120429744
# break: total_infected == 0: 0, time=0.17328823944215957
# exited on time=50.00040514435054, waiting_time=0.0011039551970661136
# exited on time=50.0001107485834, waiting_time=0.0005007557744654646
# break: total_infected == 0: 0, time=0.09284953109418756
# break: total_infected == 0: 0, time=2.43994572006647
# exited on time=50.00242383385326, waiting_time=0.0027270446577913553
# exited on time=50.00020844764548, waiting_time=0.0026454063036357583
# exited on time=50.00016780244894, waiting_time=0.0003218955949507224
# exited on time=50.00029746951658, waiting_time=0.0007100095688817177
# break: total_infected == 0: 0, time=0.1295152572252978
# break: total_infected == 0: 0, time=0.035245577035476365
# break: total_infected == 0: 0, time=3.1202862744480835
# break: total_infected == 0: 0, time=1.1071099702974214
# break: total_infected == 0: 0, time=2.4696923465417915
# exited on time=50.00044331570375, waiting_time=0.001886028271968118
# break: total_infected == 0: 0, time=0.2072969052379467
# break: total_infected == 0: 0, time=0.15022887777713223
# break: total_infected == 0: 0, time=0.3896546241211439
# break: total_infected == 0: 0, time=2.1194151311790206
# exited on time=50.0002550926011, waiting_time=0.0004608044005306675
# break: total_infected == 0: 0, time=0.3761325062181048
# break: total_infected == 0: 0, time=1.1344435479057418
# break: total_infected == 0: 0, time=0.7723628732024626
# break: total_infected == 0: 0, time=0.18404196024648795
# break: total_infected == 0: 0, time=1.3715946732517588
# exited on time=50.00206319604192, waiting_time=0.0020925967408331287
# exited on time=50.0013698321949, waiting_time=0.002328069602641897
# break: total_infected == 0: 0, time=0.01577870246759027
# break: total_infected == 0: 0, time=6.274544280242409
# break: total_infected == 0: 0, time=2.2833433991634107
# break: total_infected == 0: 0, time=1.0766207333517714
# break: total_infected == 0: 0, time=0.24478035904826767
# break: total_infected == 0: 0, time=0.29330975496895434
# break: total_infected == 0: 0, time=0.6391326415612261
# break: total_infected == 0: 0, time=0.5769566646570878
# break: total_infected == 0: 0, time=0.9154340028757012
# exited on time=50.001596833841134, waiting_time=0.0020576433192013707
# exited on time=50.00026921538001, waiting_time=0.002013276496881122
# break: total_infected == 0: 0, time=0.46721442143475955
# break: total_infected == 0: 0, time=0.5146439332937685
# break: total_infected == 0: 0, time=0.22248797774066748
# break: total_infected == 0: 0, time=0.16437179496214369
# break: total_infected == 0: 0, time=0.090077997515206
# break: total_infected == 0: 0, time=0.5404588082090854
# break: total_infected == 0: 0, time=0.10391029933259646
# break: total_infected == 0: 0, time=0.03511921342081229
# break: total_infected == 0: 0, time=0.18541026005392872
# break: total_infected == 0: 0, time=4.853468643084986
# break: total_infected == 0: 0, time=0.1595954814292302
# exited on time=50.000890291364456, waiting_time=0.0015153988649556124
# exited on time=50.00041464330959, waiting_time=0.0006938937739927785
# break: total_infected == 0: 0, time=0.5410619725075678
# exited on time=50.0000799293423, waiting_time=0.0030084768180185725
# exited on time=50.00080711564908, waiting_time=0.0037757967459930743
# break: total_infected == 0: 0, time=1.2138817815267433
# break: total_infected == 0: 0, time=0.7256422795763204
# break: total_infected == 0: 0, time=0.011444710363570833
# break: total_infected == 0: 0, time=3.5556052029420155
# break: total_infected == 0: 0, time=0.08586367272629464
# break: total_infected == 0: 0, time=2.4211489513959794
# exited on time=50.00120107270243, waiting_time=0.0014666448539121097
# break: total_infected == 0: 0, time=0.5348011966254085
# exited on time=50.00003361552363, waiting_time=0.00014859123783328394
# exited on time=50.00052157050873, waiting_time=0.0017380625248733528
# break: total_infected == 0: 0, time=0.03209582080817604
# break: total_infected == 0: 0, time=0.0458837410025224
# break: total_infected == 0: 0, time=0.012639811678568284
# break: total_infected == 0: 0, time=3.6930877196230116
# break: total_infected == 0: 0, time=0.049179210310286166
# exited on time=50.00015788591167, waiting_time=0.002329612313543772
# break: total_infected == 0: 0, time=7.238371212345052
# break: total_infected == 0: 0, time=1.4475677734878922
# exited on time=50.00030012558131, waiting_time=0.0010932461906466885
# break: total_infected == 0: 0, time=3.9362024549399517
# break: total_infected == 0: 0, time=0.1540899773631657
# exited on time=50.000715220067704, waiting_time=0.0014939249489558054
# break: total_infected == 0: 0, time=1.1060987486015665
# exited on time=50.000585593526445, waiting_time=0.0006905139599586252
# break: total_infected == 0: 0, time=4.264999588890418
# break: total_infected == 0: 0, time=1.2790010859008005
# break: total_infected == 0: 0, time=0.09815649716744546
# break: total_infected == 0: 0, time=4.409281168371246
# break: total_infected == 0: 0, time=3.9760332402944796
# break: total_infected == 0: 0, time=0.6085927805375388
# exited on time=50.001038235963655, waiting_time=0.0014281901923472004
# exited on time=50.00002498435465, waiting_time=8.452832205724714e-05
# exited on time=50.000248032178966, waiting_time=0.0011365377203855162
# exited on time=50.00021326259652, waiting_time=0.0007101354101155392
# break: total_infected == 0: 0, time=2.948430095170041
# exited on time=50.001460014748055, waiting_time=0.002269201516872079
# break: total_infected == 0: 0, time=3.6574337257255465
# break: total_infected == 0: 0, time=1.3320271226793015
# break: total_infected == 0: 0, time=0.020192209573783308
# exited on time=50.002419817334896, waiting_time=0.0038878370384527287
# exited on time=50.000260810333984, waiting_time=0.0007500096207861938
# break: total_infected == 0: 0, time=1.2040933327597703
# exited on time=50.000326583765975, waiting_time=0.0011552593659236823
# exited on time=50.00002322245364, waiting_time=0.00018317219379137184
# break: total_infected == 0: 0, time=1.43585236284935
# exited on time=50.00132048956726, waiting_time=0.003365623432826931
# exited on time=50.00043371992845, waiting_time=0.0011784174306643295
# break: total_infected == 0: 0, time=1.4831913020932976
# break: total_infected == 0: 0, time=0.16767127750238967
# break: total_infected == 0: 0, time=0.2495679602640273
# break: total_infected == 0: 0, time=0.08722363277232315
# break: total_infected == 0: 0, time=0.2877104580124854
# break: total_infected == 0: 0, time=0.17883912779841013
# exited on time=50.000915438357914, waiting_time=0.0011793514476474809
# break: total_infected == 0: 0, time=3.0243422489544765
# break: total_infected == 0: 0, time=0.8147333094559994
# break: total_infected == 0: 0, time=1.2481777556591607
# break: total_infected == 0: 0, time=2.522774951391161
# break: total_infected == 0: 0, time=0.030000550938573293
# break: total_infected == 0: 0, time=0.0877894512453469
# exited on time=50.00070149596187, waiting_time=0.007001931259937493
# break: total_infected == 0: 0, time=4.112286975326997
# exited on time=50.00161685158423, waiting_time=0.0024244690110957123
# break: total_infected == 0: 0, time=3.2457925573517272
# break: total_infected == 0: 0, time=1.474527356200086
# break: total_infected == 0: 0, time=2.1901615738942315
# break: total_infected == 0: 0, time=4.095865382078254
# break: total_infected == 0: 0, time=3.9257498727250795
# exited on time=50.00010402720235, waiting_time=0.000928262223251646
# break: total_infected == 0: 0, time=4.0298387846193
# break: total_infected == 0: 0, time=0.264305113176201
# exited on time=50.00026447480873, waiting_time=0.000505714698599198
# exited on time=50.00001545191636, waiting_time=0.0007294216280406751
# exited on time=50.00305816814286, waiting_time=0.00376290968605851
# exited on time=50.00008408928458, waiting_time=0.00028628799056555496
# break: total_infected == 0: 0, time=4.055987235664362
# exited on time=50.001328329572424, waiting_time=0.0017561691227212762
# break: total_infected == 0: 0, time=6.014959888069005
# break: total_infected == 0: 0, time=3.4597826005336727
# break: total_infected == 0: 0, time=0.03634267551009559
# exited on time=50.00009732719791, waiting_time=0.0006086206520690032
# break: total_infected == 0: 0, time=0.8261416864108398
# exited on time=50.0012423470353, waiting_time=0.0018872382470237845
# break: total_infected == 0: 0, time=1.5781443781702715
# break: total_infected == 0: 0, time=1.2472592978628687
# break: total_infected == 0: 0, time=0.49205706590596
# exited on time=50.00070522723763, waiting_time=0.001429080384339872
# break: total_infected == 0: 0, time=1.0423695480739803
# break: total_infected == 0: 0, time=0.9435683457139452
# exited on time=50.00049806918026, waiting_time=0.0012287216215584745
# break: total_infected == 0: 0, time=0.009222982413959262
# exited on time=50.000367587449134, waiting_time=0.00046132067751558057
# break: total_infected == 0: 0, time=0.05656432477486547
# exited on time=50.0000689832624, waiting_time=0.00025488020799541936
# break: total_infected == 0: 0, time=0.7595240884263924
# break: total_infected == 0: 0, time=0.029476581653048232
# break: total_infected == 0: 0, time=0.013418129854275158
# exited on time=50.00126205601324, waiting_time=0.0027466843713261097
# exited on time=50.001244678203335, waiting_time=0.0025775632173376897
# break: total_infected == 0: 0, time=0.42531281938407134
# break: total_infected == 0: 0, time=2.436666731882622
# break: total_infected == 0: 0, time=0.8079644503143332
# break: total_infected == 0: 0, time=0.566544635613679
# break: total_infected == 0: 0, time=2.1842261482450898
# exited on time=50.00070326477043, waiting_time=0.0020501605027209023
# exited on time=50.00026934290754, waiting_time=0.0006200681453597442
# exited on time=50.001502234694385, waiting_time=0.0031329637639116023
# break: total_infected == 0: 0, time=3.5188338232559073
# exited on time=50.00031127151069, waiting_time=0.00048393664455068596
# exited on time=50.00085689726252, waiting_time=0.0008893888145335434
# exited on time=50.000052683499995, waiting_time=0.00033301815763653515
# break: total_infected == 0: 0, time=1.7735779037559234
# break: total_infected == 0: 0, time=0.2686125701511488
# break: total_infected == 0: 0, time=0.11265180165946902
# exited on time=50.001682183296715, waiting_time=0.0017945500874386217
# break: total_infected == 0: 0, time=0.9254130688301074
# exited on time=50.00001281889162, waiting_time=0.0007814906292990857
# exited on time=50.000965811587484, waiting_time=0.0012971837463220627
# break: total_infected == 0: 0, time=0.031641408979508436
# exited on time=50.00050607478283, waiting_time=0.0019406120806384807
# exited on time=50.00097948567594, waiting_time=0.00122329490411071
# break: total_infected == 0: 0, time=0.12351753012080756
# break: total_infected == 0: 0, time=0.30651982274294487
# break: total_infected == 0: 0, time=1.6523962685017872
# exited on time=50.00093086742618, waiting_time=0.000987791370362015
# exited on time=50.00015103996098, waiting_time=0.00019656065091346492
# exited on time=50.0001896098985, waiting_time=0.0011563286526212
# break: total_infected == 0: 0, time=8.085374117001795
# break: total_infected == 0: 0, time=0.16114003187710882
# break: total_infected == 0: 0, time=0.08941896605664529
# exited on time=50.00000715767707, waiting_time=0.0010374230113617876
# break: total_infected == 0: 0, time=1.0873790757814397
# exited on time=50.000102410641965, waiting_time=0.00020159820718058913
# exited on time=50.0009478364941, waiting_time=0.0016057310144878103
# exited on time=50.00065764924586, waiting_time=0.001030642491950778
# exited on time=50.00021144373199, waiting_time=0.0002363994941145393
# exited on time=50.00001032045026, waiting_time=0.001026963143032626
# break: total_infected == 0: 0, time=0.11620630385979051
# break: total_infected == 0: 0, time=0.20304231987153107
# exited on time=50.00055549273393, waiting_time=0.001943683902695438
# exited on time=50.00013775974435, waiting_time=0.0006106508876824537
# break: total_infected == 0: 0, time=0.5975122363584681
# break: total_infected == 0: 0, time=2.4382514672537807
# break: total_infected == 0: 0, time=0.31748244534036024
# break: total_infected == 0: 0, time=0.33752684841106284
# break: total_infected == 0: 0, time=0.5554105121256261
# break: total_infected == 0: 0, time=2.8146553703022192
# exited on time=50.001223146352125, waiting_time=0.001661446108515891
# exited on time=50.00035060403258, waiting_time=0.0007267636645177662
# break: total_infected == 0: 0, time=0.3148290336266472
# exited on time=50.001823370992206, waiting_time=0.0018551431940924483
# break: total_infected == 0: 0, time=0.03741819239128479
# break: total_infected == 0: 0, time=0.2034197338067099
# exited on time=50.0000538022747, waiting_time=0.0010156245063703776
# exited on time=50.000797340026054, waiting_time=0.0008490720889212153
# break: total_infected == 0: 0, time=0.4054504124400352
# break: total_infected == 0: 0, time=0.042357914351142084
# break: total_infected == 0: 0, time=1.4308809423343098
# break: total_infected == 0: 0, time=0.22320029867391963
# exited on time=50.001273309214916, waiting_time=0.001829243944435549
# break: total_infected == 0: 0, time=0.8306756462340467
# exited on time=50.00137171143037, waiting_time=0.003113816801654274
# exited on time=50.00103015260462, waiting_time=0.0015505011210740136
# exited on time=50.000052770086036, waiting_time=0.000846507969978703
# break: total_infected == 0: 0, time=0.3350033011015318
# break: total_infected == 0: 0, time=1.0510705605923893
# break: total_infected == 0: 0, time=2.411366178217243
# break: total_infected == 0: 0, time=0.04566534413356502
# break: total_infected == 0: 0, time=3.530983804948738
# exited on time=50.000046048106704, waiting_time=0.000540769083512616
# break: total_infected == 0: 0, time=0.06272378181596246
# exited on time=50.00010646779065, waiting_time=0.0007281870053349942
# exited on time=50.001241799653464, waiting_time=0.003493298289858241
# exited on time=50.00024395682377, waiting_time=0.0009779004187188045
# exited on time=50.002373399797264, waiting_time=0.003697556252707058
# exited on time=50.00080451566322, waiting_time=0.0011886849036169473
# break: total_infected == 0: 0, time=1.265608564743395
# exited on time=50.00031109766098, waiting_time=0.000896326775309641
# break: total_infected == 0: 0, time=1.199598049643874
# exited on time=50.000798524599674, waiting_time=0.0022495311266242475
# exited on time=50.002959277234375, waiting_time=0.003142069966922951
# break: total_infected == 0: 0, time=0.3502105773259409
# break: total_infected == 0: 0, time=0.4045709920273988
# break: total_infected == 0: 0, time=2.8526239768368367
# exited on time=50.00080482709233, waiting_time=0.0017001962698850826
# break: total_infected == 0: 0, time=0.22750429820447013
# break: total_infected == 0: 0, time=0.17389070764685077
# exited on time=50.00128108628864, waiting_time=0.0031380576266311798
# exited on time=50.000440709482554, waiting_time=0.0010082098028925352
# exited on time=50.00023280880835, waiting_time=0.0012194489660022761
# break: total_infected == 0: 0, time=3.2159301986300757
# exited on time=50.00169684803105, waiting_time=0.0017254772130963247
# break: total_infected == 0: 0, time=6.668694017552438
# exited on time=50.000918982527445, waiting_time=0.0011477921126365608
# break: total_infected == 0: 0, time=1.246085680370953
# exited on time=50.000397431419835, waiting_time=0.001740625108649164
# break: total_infected == 0: 0, time=0.21609455656001839

# %% [markdown]
# ## Burn-in / alignment approach

# %% [markdown]
# ### Idea:
# Once an outbreak takes hold (reaches certain number of infected `k_threshold`), the subsequent dynamics (growth phase to quasi-stationary state) should look similar accross different runs, just shifted in time due to initial very variable initial phase.
#
# ### Burn-in / alignment approach:
#
# 1. Choose `k_threshold = 0.1 * N` (or a fixed number like 50 or 100)
#
# 2. For each simulation run `i` that reaches `k_threshold`, find time `t_i` when it first crosses `k_threshold`
#
# 3. Time-shift each such run `i`: `t = t - t_i`, to align the trajectory to the point where outbreak reached `k_threshold`
#
# 4. Then average all aligned trajectories, to get an average trajectory
#
# ### Similarity to complete graph:
# Once critical mass of infection is present, average rate of new infections in well connected E-R graph should behave more like on well-mixed complete graph, influenced by overall density, such that expected $a_k, b_k$ rates are $a_k, b_k$ rates for complete scaled by $p_1, p_2$.

# %%
def align_trajectories(X_sims, k_threshold, new_time_max):
    X_sims_aligned = []

    for i, X_t in enumerate(X_sims):
        times_orig = X_t[0, :].astype(float)
        infected_orig = X_t[2, :].astype(int)
        above_threshold_indices = np.where(infected_orig >= k_threshold)[0]
        if len(above_threshold_indices) > 0:
            # outbreak reached the threshold
            start_index = above_threshold_indices[0]
            start_time = times_orig[start_index]

            times_shifted = times_orig[start_index:] - start_time
            end_indices = np.where(times_shifted > new_time_max)[0]

            if len(end_indices) > 0:
                end_index = start_index + end_indices[0]
            else:
                # skip it
                print("Run ended before start_time + new_time_max")
            X_t_aligned = X_t[:, start_index:end_index].copy()

            # update times in X_t to times_shifted
            X_t_aligned[0, :] = times_shifted[:len(X_t_aligned[0,:])]
            X_sims_aligned.append(X_t_aligned)
    
    print(f"Aligned {len(X_sims_aligned)}/{len(X_sims)} trajectories.")
    return X_sims_aligned

# %%
k_threshold = 100
new_time_max = 10.0

X_sims_aligned = align_trajectories(X_sims, k_threshold, new_time_max)
# Out:
# Aligned 186/500 trajectories.

# %%
# plot X_t curves in gray and average curve in red
fig = plt.figure(dpi=150) # set DPI
ax  = plt.subplot()

for X_t in X_sims_aligned:
    ax.plot(X_t[0], X_t[2], c="blue", alpha=0.9, linewidth=0.5, rasterized=True)

avg_curve, times = get_average(X_sims_aligned, new_time_max, len(X_sims_aligned), delta_t = 0.01)

plt.axhline(y=int(0.75 * N), color='black', lw=2, alpha=0.4, linestyle='-')

plt.plot(times, avg_curve, "red")

plt.axhline(y=int(0.75 * N), color='black', lw=2, alpha=0.4, linestyle='-')

plt.xlabel("Time")
plt.ylabel("Number of Infected")
plt.grid(True)
plt.title(f"H = {g.name}, N = {N}, k_threshold = {k_threshold}, trajectories = {len(X_sims_aligned)}")
plt.savefig(f"../figures/estimation/{test_name}/gillespie-sims-aligned_SC.pdf", 
            format='pdf', bbox_inches='tight')
plt.show()
plt.close(fig) # free up memory

# %%
times
# Out:
# array([ 0.  ,  0.01,  0.02, ...,  9.98,  9.99, 10.  ], shape=(1001,))

# %% [markdown]
# ## Solve KEs and compare

# %%
I0 = 100

# solve KEs and compare
all_states = list(range(N + 1))
M = len(all_states)
# ode_system_complete = list_all_ODEs_complete(g, beta1, beta2, mu)
ode_system_random = list_all_ODEs_random(g, beta1, beta2, mu, p1, p2)

# set the initial condition
p0 = np.zeros(M)
i_set0 = all_states.index(I0)
p0[i_set0] = 1.0 # all other states have prob 0 at time 0
# p0

# %%
# solve ode_system_random over time
t_span = (0.0, new_time_max)

# times t_i to evaluate in, get saved in sol.t
steps_eval = 202
t_eval = np.linspace(t_span[0], t_span[1], steps_eval)

def f_ode(t, p):
    return ode_system_random(t, p)

sol = solve_ivp(f_ode, 
                t_span, 
                p0, 
                t_eval=t_eval,
                method="LSODA")

# %%
# plot both the expected values of p_{k}(t) 
# and the Gillespie average curve
# on the same figure

expected_values = calculate_expected_values(sol)

plt.figure()
plt.scatter(sol.t, expected_values, s = 10, color="k", 
            label=r"Expected values $E[p_{k}(t)]$")
plt.plot(sol.t, expected_values, lw=2, color="k", label="Solution of KEs")
plt.plot(times, avg_curve, 'red', label="Gillespie average curve")

plt.axhline(y=int(0.75 * N), color='black', lw=2, alpha=0.4, linestyle='-')

plt.xlabel("Time")
plt.ylabel("Number of Infected")
plt.legend()
plt.grid(True)
plt.title(f"H = {g.name}, N = {N}, k_threshold = {k_threshold}, trajectories = {len(X_sims_aligned)}")
plt.savefig(f"../figures/estimation/{test_name}/solution-vs-gillepsie_SC.pdf", 
            format='pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Calculate the estimates

# %%
## --- Calculate the estimates ---
min_Tk_threshold = 1e-6
estimates = calculate_estimates(X_sims_aligned, N, min_Tk_threshold)
# Out:
# Total events processed: 2171006

# %%
a_k_hat = estimates["a_k_hat"]
b_k_hat = estimates["b_k_hat"]
c_k_hat = estimates["c_k_hat"]

# plot only where T_k was non-zero!
valid_k_idx = estimates["T_k"] > min_Tk_threshold   

# and compare them to theoretical rates
k_values = np.arange(0, N + 1) # number of infected from 0 to N
k_choose_2 = np.array(list(map(lambda k: comb(k, 2, exact=True), k_values)))

# TODO: what are theoretical rates now?
a_k = p1 * beta1 * k_values * (N - k_values)
b_k = p2 * beta2 * k_choose_2 * (N - k_values)
c_k = mu * k_values

fig = plt.figure()
ax = plt.subplot()

# theoretical ak vs. ak hats 
ax.plot(k_values, a_k, label=r'$a_k$', color="red")
ax.scatter(k_values[valid_k_idx], a_k_hat[valid_k_idx],
        label=r'$\widehat{a}_k$', color="black", alpha=0.9)
plt.xlabel("Number of Infected")
plt.ylabel("Rates and Counts")
plt.legend()
plt.grid(True)    
plt.savefig(f"../figures/estimation/{test_name}/estimates_ak_SC.pdf", 
            format='pdf', bbox_inches='tight')    
plt.show()

# theoretical bk vs. bk hats
fig = plt.figure()
ax = plt.subplot()
ax.plot(k_values, b_k, label=r'$b_k$', color="blue")
ax.scatter(k_values[valid_k_idx], b_k_hat[valid_k_idx],
        label=r'$\widehat{b}_k$', color="black", alpha=0.9)
plt.xlabel("Number of Infected")
plt.ylabel("Rates and Estimates")
plt.legend()
plt.grid(True)    
plt.savefig(f"../figures/estimation/{test_name}/estimates_bk_SC.pdf", 
            format='pdf', bbox_inches='tight')
plt.show()

# theoretical ck vs. ck hats (as a test only)
fig = plt.figure()
ax = plt.subplot()
ax.plot(k_values, c_k, label=r'$c_k$', color="green")
ax.scatter(k_values[valid_k_idx], c_k_hat[valid_k_idx],
        label=r'$\widehat{c}_k$', color="black", alpha=0.9)
plt.xlabel("Number of Infected")
plt.ylabel("Rates and Estimates")
plt.legend()
plt.grid(True)
plt.savefig(f"../figures/estimation/{test_name}/estimates_ck_SC.pdf", 
            format='pdf', bbox_inches='tight')    
plt.show()

# %% [markdown]
# ## Solve KEs using the estimates

# %%
## --- Solve KEs using the estimates and compare ---
# --- Model 2 ---
ode_system_complete = list_all_ODEs_using_estimates(g, a_k_hat, b_k_hat, mu)

def f_ode(t, p):
    return ode_system_complete(t, p)

sol_hat = solve_ivp(f_ode, 
                    t_span, 
                    p0, 
                    t_eval=t_eval,
                    method="LSODA")

expected_values_hat = calculate_expected_values(sol_hat)

# %%
plt.figure()

# plt.plot(sol.t, expected_values_hat, color="b", label="Model 2: Solution of KEs with ak_hats, bk_hats")
plt.scatter(sol.t, expected_values_hat, color="b", s=10, alpha=.8, label="Model 2: Solution of KEs with ak_hats, bk_hats")

plt.plot(times, avg_curve, 'red', label="Gillespie average curve", alpha=0.9)

plt.axhline(y=int(0.75 * N), color='black', lw=2, alpha=0.4, linestyle='-')

plt.xlabel("Time")
plt.ylabel("Number of Infected")
plt.legend()
plt.grid(True)
plt.title(f"H = {g.name}, N = {N}, k_threshold = {k_threshold}, trajectories = {len(X_sims_aligned)}")
plt.savefig(f"../figures/estimation/{test_name}/solutions-comparison_SC.pdf", 
            format='pdf', bbox_inches='tight')
plt.show()
