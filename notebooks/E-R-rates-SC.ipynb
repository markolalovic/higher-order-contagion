# %% [markdown]
# ## Erdos-Renyi SC Rates

# %%
import numpy as np
import matplotlib.pylab as plt
import random
from scipy.special import comb

import sys
sys.path.append('../src/')
from Hypergraphs import EmptyHypergraph
from simulate_gillespie import *
from estimate_total_rates import *

sys.path.append('../scripts/')
from generators_sc import p1_p2_ER_like_simplicial_complex, ER_like_simplicial_complex

# %% [markdown]
# ## Setup

# %%
## --- Setup --- ##
test_name = "random_ER"
g_type = "random_ER"

N = 1000
I0 = 1
nsims = 500
run_gillespie_simulations = True
time_max = 50

max_pw_edges = comb(N, 2, exact=True) # N * (N - 1) / 2
max_ho_edges = comb(N, 3, exact=True) # N * (N - 1) * (N - 2) / 6

k1_k2_list = [(3, 1), (6, 2), (10, 3), (20, 6)]
(k1, k2) = k1_k2_list[3]

p1, p2 = p1_p2_ER_like_simplicial_complex(k1,k2,N)
print(f"target p1: {p1:.4f}")
print(f"target p2: {p2:.8f}\n")
print(f"target pw edges: {p1 * max_pw_edges:.0f}/{max_pw_edges:.0f}")
print(f"target ho edges: {p2 * max_ho_edges:.0f}/{max_ho_edges:.0f}\n")

giant_order_realized, edges, triangles = ER_like_simplicial_complex(N,p1,p2)
print(f"giant_order_realized = {giant_order_realized}")

all_edges = edges.tolist() + triangles.tolist()
g_edges = []
for edge in all_edges:
    g_edges.append(tuple(edge))

g = EmptyHypergraph(N)
g.name = "ER_SC"
g.set_edges(g_edges)

p1_est = len(edges) / max_pw_edges
p2_est = len(triangles) / max_ho_edges
print(f"realized p1: {p1_est:.4f}")
print(f"realized p2: {p2_est:.8f}\n")
print(f"realized pw edges:  {len(edges):.0f}/{max_pw_edges:.0f}")
print(f"realized ho edges:  {len(triangles):.0f}/{max_ho_edges:.0f}\n")

k1_sim = np.mean([len(g.neighbors(i, 1)) for i in list(g.nodes.keys())])
k2_sim = np.mean([len(g.neighbors(i, 2)) for i in list(g.nodes.keys())])
print(f"realized k1:  {k1_sim:.0f}")
print(f"realized k2:  {k2_sim:.0f}\n")

# set beta1, beta2 such that k^* = .75 N
mu    = 1             # recovery rate

# lambda_1 \in [0,3]
# lambda_2 \in [0,10]
lambda1 = 1
lambda2 = 4

beta1 = lambda1 * mu / k1 # pairwise infection rate
beta2 = lambda2 * mu / k2 # hyperedge contagion rate

# g.summary()

print(f"{test_name}: \n")
print(f"\tH = {g.name}, N = {N}, (k1, k2) = {(k1, k2)}, I0 = {I0}, time_max = {time_max},")
g.print()

print(f"\tbeta1 * N = {beta1 * N:.2f}, beta2 * N^2 = {beta2 * (N**2):.2f}, mu = {mu},")
print(f"\twith estimation based on {nsims} Gillespie simulation runs\n")
# Out:
# target p1: 0.0081
# target p2: 0.00001204
#
# target pw edges: 4049/499500
# target ho edges: 2000/166167000
#
# giant_order_realized = 999
# realized p1: 0.0199
# realized p2: 0.00001199
#
# realized pw edges:  9961/499500
# realized ho edges:  1992/166167000
#
# realized k1:  20
# realized k2:  6
#
# random_ER:
#
# 	H = ER_SC, N = 1000, (k1, k2) = (20, 6), I0 = 1, time_max = 50,
# 	ER_SC on 1000 nodes with 11953 edges.
#
# 	beta1 * N = 50.00, beta2 * N^2 = 666666.67, mu = 1,
# 	with estimation based on 500 Gillespie simulation runs

# %% [markdown]
# ## Run Gillespie

# %%
## --- Run Gillespie ---
run_gillespie_simulations = True

I0_gillespie = I0 # TODO: go over the range when necessary
nodes = list(g.nodes.keys())
initial_infections = random.sample(nodes, I0)

if run_gillespie_simulations: 
    X_sims = []
    for _ in range(nsims):
        X_t = gillespie_sim(g, beta1, beta2, mu, initial_infections, time_max)
        X_sims.append(X_t)

    # save the simulation results
    sim_results = {f'sim_{i}': X_sims[i] for i in range(nsims)}
    np.savez_compressed(f'../results/gillespie-sims_{test_name}_SC.npz', **sim_results)
else: 
    # load simulation results
    sim_results = np.load(f'../results/gillespie-sims_{test_name}_SC.npz', allow_pickle=True)
    X_sims = [sim_results[f'sim_{i}'] for i in range(nsims)]

# plot X_t curves in gray and average curve in red
fig = plt.figure(dpi=150) # set DPI
ax  = plt.subplot()

for X_t in X_sims:
    ax.plot(X_t[0], X_t[2], c="blue", alpha=0.9, linewidth=0.5, rasterized=True)

plt.axhline(y=int(0.75 * N), color='black', lw=2, alpha=0.4, linestyle='-')

plt.xlabel("Time")
plt.ylabel("Number of Infected")
plt.grid(True)
plt.title(f"H = {g.name}, N = {N}, I0 = {I0}, nsims = {nsims}")
plt.savefig(f"../figures/estimation/{test_name}/gillespie-sims_SC.pdf", 
            format='pdf', bbox_inches='tight')
plt.show()
plt.close(fig) # free up memory
# Out:
# break: total_infected == 0: 0, time=10.76889749543579
# break: total_infected == 0: 0, time=4.322023796152987
# break: total_infected == 0: 0, time=1.6769935631042032
# exited on time=50.000936947905096, waiting_time=0.001143334408315346
# break: total_infected == 0: 0, time=0.34705849598773997
# break: total_infected == 0: 0, time=2.0460019070987556
# break: total_infected == 0: 0, time=0.7545345765443487
# break: total_infected == 0: 0, time=0.14846291885324753
# break: total_infected == 0: 0, time=0.6321306714468223
# break: total_infected == 0: 0, time=0.4050268475900157
# break: total_infected == 0: 0, time=3.412750867565744
# exited on time=50.00017491830631, waiting_time=0.0005267118400183679
# break: total_infected == 0: 0, time=7.319390313055043
# break: total_infected == 0: 0, time=0.030052459247389553
# exited on time=50.00008844231767, waiting_time=0.0003386071354064576
# break: total_infected == 0: 0, time=1.1457320369023807
# break: total_infected == 0: 0, time=5.746746971995456
# break: total_infected == 0: 0, time=0.9541836895046772
# break: total_infected == 0: 0, time=0.822947995372185
# break: total_infected == 0: 0, time=0.07844259746451505
# exited on time=50.00039049692271, waiting_time=0.000404917648613003
# break: total_infected == 0: 0, time=0.342004376377247
# exited on time=50.00147322258872, waiting_time=0.0020979959291526087
# exited on time=50.00000050663023, waiting_time=6.270124087890675e-05
# break: total_infected == 0: 0, time=2.0717932842668203
# break: total_infected == 0: 0, time=0.3680441100557416
# exited on time=50.000028255203404, waiting_time=0.0004309711137162943
# break: total_infected == 0: 0, time=1.1916033862732072
# break: total_infected == 0: 0, time=8.25333400017901
# break: total_infected == 0: 0, time=0.1666127507326448
# break: total_infected == 0: 0, time=0.35962788884301383
# break: total_infected == 0: 0, time=3.2109758384296767
# break: total_infected == 0: 0, time=0.4515496883941034
# break: total_infected == 0: 0, time=0.18389797096976906
# break: total_infected == 0: 0, time=0.4963372904874272
# break: total_infected == 0: 0, time=1.379745464389653
# break: total_infected == 0: 0, time=0.24150767500920667
# break: total_infected == 0: 0, time=0.061933994923582696
# exited on time=50.002144505994124, waiting_time=0.0025363648431138584
# break: total_infected == 0: 0, time=0.04282132804021737
# break: total_infected == 0: 0, time=0.3785521213239924
# break: total_infected == 0: 0, time=2.969310854345596
# break: total_infected == 0: 0, time=5.512772848315424
# break: total_infected == 0: 0, time=0.8999558140523672
# break: total_infected == 0: 0, time=6.613374056164845
# break: total_infected == 0: 0, time=1.9688843793899224
# break: total_infected == 0: 0, time=0.12480128119296358
# break: total_infected == 0: 0, time=0.12035736239385429
# break: total_infected == 0: 0, time=2.588443877145631
# break: total_infected == 0: 0, time=2.261621997192929
# break: total_infected == 0: 0, time=7.237928501207006
# break: total_infected == 0: 0, time=3.300659116977538
# break: total_infected == 0: 0, time=0.11596636281173774
# break: total_infected == 0: 0, time=1.0985921876275961
# break: total_infected == 0: 0, time=0.6461338993156835
# break: total_infected == 0: 0, time=0.2676724989525831
# break: total_infected == 0: 0, time=1.2198570207464838
# break: total_infected == 0: 0, time=0.03821712962006951
# break: total_infected == 0: 0, time=9.229624316893144
# break: total_infected == 0: 0, time=1.0889459214965624
# break: total_infected == 0: 0, time=1.1797336796199476
# break: total_infected == 0: 0, time=0.0036029107557191114
# break: total_infected == 0: 0, time=0.4471233063023498
# break: total_infected == 0: 0, time=0.015392656923887858
# break: total_infected == 0: 0, time=0.7108383303978618
# break: total_infected == 0: 0, time=6.301465891868847
# exited on time=50.00152336529861, waiting_time=0.001994987744088676
# break: total_infected == 0: 0, time=0.28430111719744644
# break: total_infected == 0: 0, time=0.03880660935694959
# break: total_infected == 0: 0, time=6.40080621366693
# break: total_infected == 0: 0, time=0.2699588793449021
# break: total_infected == 0: 0, time=0.09971609301090598
# break: total_infected == 0: 0, time=0.07211948590474285
# break: total_infected == 0: 0, time=1.8575292416800906
# break: total_infected == 0: 0, time=1.260489810819082
# break: total_infected == 0: 0, time=3.3166377831961382
# break: total_infected == 0: 0, time=1.077280962584889
# break: total_infected == 0: 0, time=4.693557352651356
# break: total_infected == 0: 0, time=1.0220400441358146
# exited on time=50.000448677064895, waiting_time=0.0012091705784731707
# break: total_infected == 0: 0, time=0.22653570610620216
# break: total_infected == 0: 0, time=0.28838980026097716
# break: total_infected == 0: 0, time=0.09865410099630563
# break: total_infected == 0: 0, time=0.6685380507676785
# break: total_infected == 0: 0, time=0.2640387945443673
# break: total_infected == 0: 0, time=0.5647571071143278
# break: total_infected == 0: 0, time=5.003906949987575
# break: total_infected == 0: 0, time=0.1092457992423805
# break: total_infected == 0: 0, time=0.04043271920987315
# exited on time=50.00220941857383, waiting_time=0.004338790093370916
# break: total_infected == 0: 0, time=0.21862476496585384
# break: total_infected == 0: 0, time=0.1480390119831931
# break: total_infected == 0: 0, time=3.2819936154559466
# break: total_infected == 0: 0, time=0.002469621261687686
# break: total_infected == 0: 0, time=1.1362519759265437
# break: total_infected == 0: 0, time=0.13020036261444476
# exited on time=50.00019375284686, waiting_time=0.0016487134497313667
# break: total_infected == 0: 0, time=0.8392229713365024
# break: total_infected == 0: 0, time=4.0640005284548115
# break: total_infected == 0: 0, time=0.6625275712195122
# exited on time=50.00007914714617, waiting_time=0.0001777942512527012
# break: total_infected == 0: 0, time=1.8437109564159477
# break: total_infected == 0: 0, time=1.424861325399179
# break: total_infected == 0: 0, time=0.17642253105541247
# break: total_infected == 0: 0, time=0.025729807607179047
# break: total_infected == 0: 0, time=0.1578577118696261
# break: total_infected == 0: 0, time=0.3141833712925564
# break: total_infected == 0: 0, time=0.5109583007610028
# break: total_infected == 0: 0, time=0.2605175821771918
# break: total_infected == 0: 0, time=0.6026670575105895
# break: total_infected == 0: 0, time=1.7762480189499394
# break: total_infected == 0: 0, time=0.11186588038327192
# break: total_infected == 0: 0, time=1.240333102713639
# break: total_infected == 0: 0, time=0.4927658581600931
# break: total_infected == 0: 0, time=0.9541388864024155
# break: total_infected == 0: 0, time=0.7464727763357705
# break: total_infected == 0: 0, time=1.2880138034308517
# break: total_infected == 0: 0, time=1.6886091958606249
# break: total_infected == 0: 0, time=0.15520846480811498
# break: total_infected == 0: 0, time=1.7239262409269058
# break: total_infected == 0: 0, time=1.587734294754252
# break: total_infected == 0: 0, time=0.36899766532037015
# break: total_infected == 0: 0, time=1.0441229878567442
# break: total_infected == 0: 0, time=1.7424896474661018
# break: total_infected == 0: 0, time=0.31855617595294095
# exited on time=50.00064720680395, waiting_time=0.0023612543415455476
# break: total_infected == 0: 0, time=0.8107068677329666
# break: total_infected == 0: 0, time=0.1923299240369718
# break: total_infected == 0: 0, time=0.7868654814452799
# break: total_infected == 0: 0, time=0.4460365095430074
# break: total_infected == 0: 0, time=0.694858300182766
# break: total_infected == 0: 0, time=0.8133291480078123
# break: total_infected == 0: 0, time=5.780102418394714
# break: total_infected == 0: 0, time=0.6751398968808967
# break: total_infected == 0: 0, time=0.1063021690996973
# break: total_infected == 0: 0, time=0.544392355095862
# break: total_infected == 0: 0, time=0.5052712199258231
# break: total_infected == 0: 0, time=7.958639351339249
# break: total_infected == 0: 0, time=0.15865453154372783
# break: total_infected == 0: 0, time=1.4791705559099422
# break: total_infected == 0: 0, time=0.15512289693074469
# break: total_infected == 0: 0, time=3.7532448476111635
# break: total_infected == 0: 0, time=3.1117455190937475
# break: total_infected == 0: 0, time=0.1786332284039614
# break: total_infected == 0: 0, time=1.878572012706742
# break: total_infected == 0: 0, time=0.5414219540357332
# exited on time=50.00056422217952, waiting_time=0.0015728560549054234
# break: total_infected == 0: 0, time=0.08535518066144321
# exited on time=50.00032952624655, waiting_time=0.0007618883307376665
# break: total_infected == 0: 0, time=0.1528149604139127
# break: total_infected == 0: 0, time=0.9887253115058164
# break: total_infected == 0: 0, time=0.4003020859357074
# break: total_infected == 0: 0, time=1.875728701862827
# exited on time=50.00042036805268, waiting_time=0.0008806582369597417
# break: total_infected == 0: 0, time=0.32791053192149017
# break: total_infected == 0: 0, time=0.6886969958237685
# break: total_infected == 0: 0, time=0.5050983589631899
# break: total_infected == 0: 0, time=0.04063927224727667
# break: total_infected == 0: 0, time=2.318385517794697
# break: total_infected == 0: 0, time=0.005006565086777662
# break: total_infected == 0: 0, time=1.0547441941744562
# break: total_infected == 0: 0, time=3.0409047371528892
# break: total_infected == 0: 0, time=0.24968347139840966
# break: total_infected == 0: 0, time=0.2502871338157095
# break: total_infected == 0: 0, time=1.397743565296312
# break: total_infected == 0: 0, time=0.6124761851502515
# break: total_infected == 0: 0, time=1.4741289623095928
# exited on time=50.001161018418586, waiting_time=0.002144677749843458
# break: total_infected == 0: 0, time=1.163548525863717
# break: total_infected == 0: 0, time=0.8574830740047521
# break: total_infected == 0: 0, time=0.1069291377502884
# break: total_infected == 0: 0, time=3.8191315946712225
# exited on time=50.00001361074624, waiting_time=0.0010936820734432874
# break: total_infected == 0: 0, time=0.03528016532378851
# exited on time=50.000797420003046, waiting_time=0.0008515426864986467
# break: total_infected == 0: 0, time=4.369075007054733
# exited on time=50.001023117152535, waiting_time=0.001255797622269469
# break: total_infected == 0: 0, time=0.2290662589763887
# break: total_infected == 0: 0, time=5.223448211768268
# break: total_infected == 0: 0, time=0.02463246048478111
# break: total_infected == 0: 0, time=0.6287952575284851
# exited on time=50.000592984082324, waiting_time=0.0005999653260388079
# break: total_infected == 0: 0, time=4.031470080271063
# break: total_infected == 0: 0, time=5.308117776819657
# break: total_infected == 0: 0, time=1.5588168960853899
# break: total_infected == 0: 0, time=0.47819199968432446
# break: total_infected == 0: 0, time=0.08264346375764052
# exited on time=50.000469170673405, waiting_time=0.0006490277624871313
# break: total_infected == 0: 0, time=0.03366816476952147
# break: total_infected == 0: 0, time=0.12090768942508692
# break: total_infected == 0: 0, time=1.6414075631310006
# break: total_infected == 0: 0, time=0.6328139317633636
# break: total_infected == 0: 0, time=6.225722793033192
# break: total_infected == 0: 0, time=0.18082938880142016
# break: total_infected == 0: 0, time=0.5831978666700017
# break: total_infected == 0: 0, time=1.3907958885369605
# exited on time=50.00028176604955, waiting_time=0.0008191506565195116
# break: total_infected == 0: 0, time=0.7899925085441715
# break: total_infected == 0: 0, time=1.7518279787219067
# exited on time=50.00086057115413, waiting_time=0.0009517355077241123
# exited on time=50.00113851628929, waiting_time=0.0023752962074983443
# break: total_infected == 0: 0, time=0.8061218319537226
# break: total_infected == 0: 0, time=0.4819370243608335
# break: total_infected == 0: 0, time=0.8892954081685114
# break: total_infected == 0: 0, time=1.0878690990669422
# break: total_infected == 0: 0, time=2.1181043908662716
# break: total_infected == 0: 0, time=12.424973851836096
# exited on time=50.000133884720185, waiting_time=0.0011738804170772683
# exited on time=50.00155938029835, waiting_time=0.003079297780727021
# break: total_infected == 0: 0, time=0.02644520455735458
# break: total_infected == 0: 0, time=1.417063177419172
# break: total_infected == 0: 0, time=16.770217542697388
# exited on time=50.000319870402606, waiting_time=0.0022976769741622776
# break: total_infected == 0: 0, time=9.610259781382693
# break: total_infected == 0: 0, time=0.03644132646325371
# break: total_infected == 0: 0, time=0.3068336166751929
# break: total_infected == 0: 0, time=0.13953885704710237
# break: total_infected == 0: 0, time=0.10464718093911657
# break: total_infected == 0: 0, time=4.724991122560611
# break: total_infected == 0: 0, time=0.5809045881108953
# break: total_infected == 0: 0, time=0.20683576719646563
# break: total_infected == 0: 0, time=4.077308101638206
# break: total_infected == 0: 0, time=0.6930787556665343
# break: total_infected == 0: 0, time=1.4334100242467556
# break: total_infected == 0: 0, time=0.46367914670715454
# break: total_infected == 0: 0, time=0.11762130424090443
# break: total_infected == 0: 0, time=0.996600149144403
# break: total_infected == 0: 0, time=1.2082455027688275
# break: total_infected == 0: 0, time=0.47277682675567206
# break: total_infected == 0: 0, time=1.1877053766884185
# break: total_infected == 0: 0, time=1.271275548995049
# break: total_infected == 0: 0, time=1.827264309790058
# break: total_infected == 0: 0, time=0.15305493501298587
# break: total_infected == 0: 0, time=2.3899779413807876
# break: total_infected == 0: 0, time=0.6739258538283212
# break: total_infected == 0: 0, time=2.8965363644444224
# break: total_infected == 0: 0, time=2.236580165711213
# exited on time=50.000783864527065, waiting_time=0.0010783126390603783
# break: total_infected == 0: 0, time=9.82579096350851
# break: total_infected == 0: 0, time=0.2015700374367483
# break: total_infected == 0: 0, time=3.9277163365539614
# break: total_infected == 0: 0, time=0.4932241390295706
# break: total_infected == 0: 0, time=0.8069452132104878
# break: total_infected == 0: 0, time=0.16942071023112157
# exited on time=50.00071149898826, waiting_time=0.001092376621287775
# break: total_infected == 0: 0, time=0.7034721262625679
# break: total_infected == 0: 0, time=3.1256463881488092
# break: total_infected == 0: 0, time=0.4266851296463725
# break: total_infected == 0: 0, time=1.2106320383232443
# break: total_infected == 0: 0, time=2.3496524773564325
# break: total_infected == 0: 0, time=0.1755970112859259
# break: total_infected == 0: 0, time=0.3036311475902742
# break: total_infected == 0: 0, time=0.03107387576170173
# break: total_infected == 0: 0, time=1.413415128101732
# break: total_infected == 0: 0, time=1.488064661726534
# break: total_infected == 0: 0, time=1.859749269414913
# exited on time=50.00090915576499, waiting_time=0.0010949900543045434
# break: total_infected == 0: 0, time=0.3322204850890879
# break: total_infected == 0: 0, time=0.2593337753450068
# exited on time=50.001328463207045, waiting_time=0.0026791054430445865
# break: total_infected == 0: 0, time=6.754367821194798
# break: total_infected == 0: 0, time=1.5384122897534274
# break: total_infected == 0: 0, time=0.013276345777048525
# break: total_infected == 0: 0, time=0.14839516555793808
# break: total_infected == 0: 0, time=0.931905245311213
# break: total_infected == 0: 0, time=1.2140227827169434
# break: total_infected == 0: 0, time=1.3703925133416055
# break: total_infected == 0: 0, time=2.6165705581058885
# break: total_infected == 0: 0, time=2.2586221041973693
# break: total_infected == 0: 0, time=4.351979339861138
# break: total_infected == 0: 0, time=1.3861358696699866
# break: total_infected == 0: 0, time=1.1490148068806532
# break: total_infected == 0: 0, time=0.02402637833559133
# break: total_infected == 0: 0, time=0.32741609588667103
# break: total_infected == 0: 0, time=3.352768282023208
# break: total_infected == 0: 0, time=0.41530398181230543
# break: total_infected == 0: 0, time=2.3633769391329054
# break: total_infected == 0: 0, time=0.6551507756870378
# break: total_infected == 0: 0, time=1.659859692094162
# exited on time=50.0002107495325, waiting_time=0.0002477731562739188
# break: total_infected == 0: 0, time=0.25160846485671434
# break: total_infected == 0: 0, time=1.555402274117176
# break: total_infected == 0: 0, time=3.0173494874678455
# exited on time=50.00012644151942, waiting_time=0.00039109341335676274
# break: total_infected == 0: 0, time=0.04559943305928119
# break: total_infected == 0: 0, time=0.31269158564166494
# break: total_infected == 0: 0, time=1.129346383715848
# break: total_infected == 0: 0, time=0.27308369625570056
# break: total_infected == 0: 0, time=3.219876917442353
# exited on time=50.00022288650455, waiting_time=0.0007892447544261906
# break: total_infected == 0: 0, time=0.2748892240146404
# break: total_infected == 0: 0, time=0.4506758394730282
# exited on time=50.00023231207442, waiting_time=0.0008563819331888904
# break: total_infected == 0: 0, time=2.876601624681406
# break: total_infected == 0: 0, time=0.7516061561563003
# break: total_infected == 0: 0, time=7.422933371509586
# exited on time=50.00141672723323, waiting_time=0.0018573622135787146
# break: total_infected == 0: 0, time=3.6919092964474265
# break: total_infected == 0: 0, time=0.6104960584506118
# break: total_infected == 0: 0, time=0.08570006533137144
# break: total_infected == 0: 0, time=0.10432863425814881
# break: total_infected == 0: 0, time=0.4133685388474968
# break: total_infected == 0: 0, time=0.1565684191630399
# exited on time=50.00009838578694, waiting_time=0.001322727584588345
# exited on time=50.00006817501138, waiting_time=0.00021239440009776533
# break: total_infected == 0: 0, time=5.386600161130532
# break: total_infected == 0: 0, time=3.230343245768629
# break: total_infected == 0: 0, time=0.1446173538300989
# break: total_infected == 0: 0, time=0.24954455426854616
# break: total_infected == 0: 0, time=0.6518933510414343
# break: total_infected == 0: 0, time=2.192739181692095
# exited on time=50.001605630459636, waiting_time=0.0018874009718681274
# break: total_infected == 0: 0, time=1.1322707177303788
# break: total_infected == 0: 0, time=0.13631526436155375
# break: total_infected == 0: 0, time=0.1535228129073069
# break: total_infected == 0: 0, time=2.003130570340496
# break: total_infected == 0: 0, time=5.507662803316016
# break: total_infected == 0: 0, time=0.06362231896697783
# break: total_infected == 0: 0, time=2.587603534876801
# break: total_infected == 0: 0, time=1.0765688836727816
# break: total_infected == 0: 0, time=1.44980768866654
# exited on time=50.00117909666005, waiting_time=0.0012171879654830867
# break: total_infected == 0: 0, time=0.006462818888303689
# break: total_infected == 0: 0, time=0.12891204461357647
# break: total_infected == 0: 0, time=0.03050185912483977
# break: total_infected == 0: 0, time=3.3954664423207834
# break: total_infected == 0: 0, time=0.7113314656974892
# break: total_infected == 0: 0, time=0.07365022324378949
# break: total_infected == 0: 0, time=1.8110486360826188
# break: total_infected == 0: 0, time=0.051293790328835305
# break: total_infected == 0: 0, time=0.04847108484158756
# break: total_infected == 0: 0, time=5.0109493417690825
# break: total_infected == 0: 0, time=0.0984734676087886
# break: total_infected == 0: 0, time=1.8371149825305024
# exited on time=50.00036008239747, waiting_time=0.0005399702168159364
# break: total_infected == 0: 0, time=1.0345321443283528
# break: total_infected == 0: 0, time=0.2540627504973272
# break: total_infected == 0: 0, time=3.8986641427553352
# break: total_infected == 0: 0, time=0.9487607154945433
# exited on time=50.00182329608327, waiting_time=0.0024322052778012323
# break: total_infected == 0: 0, time=1.9132108142256965
# break: total_infected == 0: 0, time=0.42697416174188113
# break: total_infected == 0: 0, time=0.007844469749094526
# exited on time=50.000719523830256, waiting_time=0.0007833278687354895
# break: total_infected == 0: 0, time=7.233737609171241
# break: total_infected == 0: 0, time=1.2925333040733917
# break: total_infected == 0: 0, time=6.970315665477376
# break: total_infected == 0: 0, time=15.429295748145494
# break: total_infected == 0: 0, time=0.1337152651656404
# exited on time=50.00016270449019, waiting_time=0.0005902599029547252
# break: total_infected == 0: 0, time=0.7186937689799051
# break: total_infected == 0: 0, time=0.6565828845821619
# break: total_infected == 0: 0, time=7.10872715424681
# exited on time=50.000533627069224, waiting_time=0.0007057637703977472
# break: total_infected == 0: 0, time=0.08972582306831611
# break: total_infected == 0: 0, time=4.933663369647859
# break: total_infected == 0: 0, time=3.2660914455315564
# exited on time=50.00060806712516, waiting_time=0.002174306926345546
# break: total_infected == 0: 0, time=0.5485061549230746
# exited on time=50.0009812572454, waiting_time=0.0021134924539712597
# break: total_infected == 0: 0, time=0.17065331578094586
# break: total_infected == 0: 0, time=0.08251105796221507
# break: total_infected == 0: 0, time=0.991584209748278
# break: total_infected == 0: 0, time=0.7716335006367793
# break: total_infected == 0: 0, time=0.09074631012109512
# break: total_infected == 0: 0, time=0.1038766675153634
# break: total_infected == 0: 0, time=0.2375342926060044
# break: total_infected == 0: 0, time=2.288874259785093
# break: total_infected == 0: 0, time=0.1907444936522499
# break: total_infected == 0: 0, time=0.3114632781890995
# break: total_infected == 0: 0, time=0.49525798238717067
# break: total_infected == 0: 0, time=0.21730066468985407
# exited on time=50.00022669751456, waiting_time=0.0009028816829114888
# break: total_infected == 0: 0, time=1.5890071078839996
# break: total_infected == 0: 0, time=0.8424600022085641
# break: total_infected == 0: 0, time=4.5610853478222815
# break: total_infected == 0: 0, time=0.33305815773156294
# break: total_infected == 0: 0, time=1.2278685020631455
# break: total_infected == 0: 0, time=1.0960840489588781
# break: total_infected == 0: 0, time=0.03936239130954065
# break: total_infected == 0: 0, time=0.14988170822570107
# break: total_infected == 0: 0, time=0.012608356803204181
# break: total_infected == 0: 0, time=0.32285954945301343
# break: total_infected == 0: 0, time=1.1432351905212552
# break: total_infected == 0: 0, time=1.30400438445728
# break: total_infected == 0: 0, time=1.3465397835432231
# break: total_infected == 0: 0, time=7.796976140651216
# break: total_infected == 0: 0, time=0.26130708375091516
# exited on time=50.000609622410856, waiting_time=0.0011146347325110442
# exited on time=50.00022276233089, waiting_time=0.003728552763408076
# exited on time=50.00056913069155, waiting_time=0.0018163556897013496
# break: total_infected == 0: 0, time=1.9583071726510022
# break: total_infected == 0: 0, time=0.28093968720131024
# break: total_infected == 0: 0, time=0.13610419254434178
# break: total_infected == 0: 0, time=0.4335648992191485
# break: total_infected == 0: 0, time=0.06739074764108936
# break: total_infected == 0: 0, time=0.0846589191370519
# break: total_infected == 0: 0, time=0.12942360741551787
# break: total_infected == 0: 0, time=1.3272987256396038
# break: total_infected == 0: 0, time=0.26305697071849987
# exited on time=50.000251152808076, waiting_time=0.0010147701038117024
# break: total_infected == 0: 0, time=14.297469215048942
# break: total_infected == 0: 0, time=0.11262628457108953
# break: total_infected == 0: 0, time=0.462818756872443
# break: total_infected == 0: 0, time=7.010501315028911
# exited on time=50.00012723248805, waiting_time=0.000563851577805975
# break: total_infected == 0: 0, time=1.3338571884308694
# exited on time=50.000211563368396, waiting_time=0.00031815147755470354
# break: total_infected == 0: 0, time=0.40303131307772355
# break: total_infected == 0: 0, time=0.851192022502169
# break: total_infected == 0: 0, time=0.678393339616164
# break: total_infected == 0: 0, time=0.22709410612293618
# break: total_infected == 0: 0, time=0.27460545979585366
# break: total_infected == 0: 0, time=0.9284028840166396
# exited on time=50.00007289064882, waiting_time=0.0012414026151588871
# break: total_infected == 0: 0, time=0.894842199844463
# break: total_infected == 0: 0, time=0.029316373205605026
# break: total_infected == 0: 0, time=0.4320702567118537
# exited on time=50.00012417488014, waiting_time=0.0006820905884261846
# break: total_infected == 0: 0, time=0.4569347260166907
# break: total_infected == 0: 0, time=0.43439202178516106
# break: total_infected == 0: 0, time=7.862152427083272
# break: total_infected == 0: 0, time=0.24776923737347806
# break: total_infected == 0: 0, time=0.746564598814509
# exited on time=50.000053729930265, waiting_time=0.0008211099802117258
# exited on time=50.001288462298525, waiting_time=0.0015464464616589159
# break: total_infected == 0: 0, time=2.168783138375117
# break: total_infected == 0: 0, time=3.7879184871020235
# break: total_infected == 0: 0, time=0.2802007378077245
# break: total_infected == 0: 0, time=0.6525713351423249
# break: total_infected == 0: 0, time=0.12509476910664902
# break: total_infected == 0: 0, time=1.076360159753036
# exited on time=50.00070564395505, waiting_time=0.0009233669015292178
# break: total_infected == 0: 0, time=0.48855421745645067
# break: total_infected == 0: 0, time=0.17226135991689814
# break: total_infected == 0: 0, time=1.1076804710778079
# break: total_infected == 0: 0, time=0.25278575136112247
# break: total_infected == 0: 0, time=0.5406971964921169
# exited on time=50.00000216846832, waiting_time=0.0012267027012067397
# break: total_infected == 0: 0, time=0.5286717207333608
# break: total_infected == 0: 0, time=0.03832501419550594
# break: total_infected == 0: 0, time=3.2522969112258266
# break: total_infected == 0: 0, time=0.1575514259273785
# exited on time=50.000446235018195, waiting_time=0.0004497206135008971
# break: total_infected == 0: 0, time=0.7629806068496617
# break: total_infected == 0: 0, time=0.7376598576170452
# break: total_infected == 0: 0, time=0.000237876458079172
# exited on time=50.00037212125624, waiting_time=0.0019083140727152786
# break: total_infected == 0: 0, time=0.38952420850274705
# break: total_infected == 0: 0, time=0.21152986189869286
# break: total_infected == 0: 0, time=0.10878692884314772
# exited on time=50.00189225199406, waiting_time=0.0021022747027923724
# break: total_infected == 0: 0, time=0.10815180196823392
# break: total_infected == 0: 0, time=0.31659342184949557
# break: total_infected == 0: 0, time=4.3219183272157204
# break: total_infected == 0: 0, time=0.1553174326065141
# break: total_infected == 0: 0, time=0.9038174952421267
# break: total_infected == 0: 0, time=5.9761758395763
# break: total_infected == 0: 0, time=4.506013136026804
# break: total_infected == 0: 0, time=0.486924746463547
# break: total_infected == 0: 0, time=1.874636614704694
# break: total_infected == 0: 0, time=0.03727806828669685
# break: total_infected == 0: 0, time=0.13823748376559752
# break: total_infected == 0: 0, time=0.1570734291771324
# exited on time=50.00068548529184, waiting_time=0.0009707605134399387
# break: total_infected == 0: 0, time=0.4637864330884687
# break: total_infected == 0: 0, time=0.0461292667252058
# break: total_infected == 0: 0, time=0.4900882398934588
# break: total_infected == 0: 0, time=0.14241776357963778
# break: total_infected == 0: 0, time=0.9278182575591369
# break: total_infected == 0: 0, time=1.043569959632279
# break: total_infected == 0: 0, time=1.1167004654004018
# break: total_infected == 0: 0, time=0.06317590174272417
# break: total_infected == 0: 0, time=3.5394465409623
# exited on time=50.000003613829726, waiting_time=0.0005354940732806906
# break: total_infected == 0: 0, time=0.7348120876993636
# break: total_infected == 0: 0, time=0.5846100182924259
# break: total_infected == 0: 0, time=2.3027038765863708
# break: total_infected == 0: 0, time=7.492886108551631
# exited on time=50.00314831206082, waiting_time=0.003380267117621835
# break: total_infected == 0: 0, time=6.578269926279278
# exited on time=50.00232602262207, waiting_time=0.002517262362595994
# break: total_infected == 0: 0, time=1.4999546092748897
# break: total_infected == 0: 0, time=0.9568269067700993
# break: total_infected == 0: 0, time=3.431352912471657
# break: total_infected == 0: 0, time=0.29103196799377556
# break: total_infected == 0: 0, time=0.7313719358952934
# break: total_infected == 0: 0, time=0.13286516756864497
# break: total_infected == 0: 0, time=0.2145645865373363
# exited on time=50.000884220096076, waiting_time=0.001604445468725206
# break: total_infected == 0: 0, time=1.1415053586651647
# break: total_infected == 0: 0, time=2.275566892182362
# break: total_infected == 0: 0, time=0.3979267444434896
# break: total_infected == 0: 0, time=0.4309938795041617
# break: total_infected == 0: 0, time=0.47454131989478104
# break: total_infected == 0: 0, time=0.13371577300566445
# exited on time=50.000385347845295, waiting_time=0.0007936991211808405
# break: total_infected == 0: 0, time=0.5470327092357181
# exited on time=50.00153053494459, waiting_time=0.002558060246693558
# break: total_infected == 0: 0, time=0.5282825468573491

# %% [markdown]
# ## Burn-in / alignment approach

# %% [markdown]
# ### Idea:
# Once an outbreak takes hold (reaches certain number of infected `k_threshold`), the subsequent dynamics (growth phase to quasi-stationary state) should look similar accross different runs, just shifted in time due to initial very variable initial phase.
#
# ### Burn-in / alignment approach:
#
# 1. Choose `k_threshold = 0.1 * N` (or a fixed number like 50 or 100)
#
# 2. For each simulation run `i` that reaches `k_threshold`, find time `t_i` when it first crosses `k_threshold`
#
# 3. Time-shift each such run `i`: `t = t - t_i`, to align the trajectory to the point where outbreak reached `k_threshold`
#
# 4. Then average all aligned trajectories, to get an average trajectory
#
# ### Similarity to complete graph:
# Once critical mass of infection is present, average rate of new infections in well connected E-R graph should behave more like on well-mixed complete graph, influenced by overall density, such that expected $a_k, b_k$ rates are $a_k, b_k$ rates for complete scaled by $p_1, p_2$.

# %%
def align_trajectories(X_sims, k_threshold, new_time_max):
    X_sims_aligned = []

    for i, X_t in enumerate(X_sims):
        times_orig = X_t[0, :].astype(float)
        infected_orig = X_t[2, :].astype(int)
        above_threshold_indices = np.where(infected_orig >= k_threshold)[0]
        if len(above_threshold_indices) > 0:
            # outbreak reached the threshold
            start_index = above_threshold_indices[0]
            start_time = times_orig[start_index]

            times_shifted = times_orig[start_index:] - start_time
            end_indices = np.where(times_shifted > new_time_max)[0]

            if len(end_indices) > 0:
                end_index = start_index + end_indices[0]
            else:
                # skip it
                print("Run ended before start_time + new_time_max")
            X_t_aligned = X_t[:, start_index:end_index].copy()

            # update times in X_t to times_shifted
            X_t_aligned[0, :] = times_shifted[:len(X_t_aligned[0,:])]
            X_sims_aligned.append(X_t_aligned)
    
    print(f"Aligned {len(X_sims_aligned)}/{len(X_sims)} trajectories.")
    return X_sims_aligned

# %%
k_threshold = 100
new_time_max = 10.0

X_sims_aligned = align_trajectories(X_sims, k_threshold, new_time_max)
# Out:
# Aligned 72/500 trajectories.

# %%
# plot X_t curves in gray and average curve in red
fig = plt.figure(dpi=150) # set DPI
ax  = plt.subplot()

for X_t in X_sims_aligned:
    ax.plot(X_t[0], X_t[2], c="blue", alpha=0.9, linewidth=0.5, rasterized=True)

avg_curve, times = get_average(X_sims_aligned, new_time_max, len(X_sims_aligned), delta_t = 0.01)

plt.axhline(y=int(0.75 * N), color='black', lw=2, alpha=0.4, linestyle='-')

plt.plot(times, avg_curve, "red")

plt.axhline(y=int(0.75 * N), color='black', lw=2, alpha=0.4, linestyle='-')

plt.xlabel("Time")
plt.ylabel("Number of Infected")
plt.grid(True)
plt.title(f"H = {g.name}, N = {N}, k_threshold = {k_threshold}, trajectories = {len(X_sims_aligned)}")
plt.savefig(f"../figures/estimation/{test_name}/gillespie-sims-aligned_SC.pdf", 
            format='pdf', bbox_inches='tight')
plt.show()
plt.close(fig) # free up memory

# %%
times
# Out:
# array([ 0.  ,  0.01,  0.02, ...,  9.98,  9.99, 10.  ], shape=(1001,))

# %% [markdown]
# ## Solve KEs and compare

# %%
I0 = 100

# solve KEs and compare
all_states = list(range(N + 1))
M = len(all_states)
# ode_system_complete = list_all_ODEs_complete(g, beta1, beta2, mu)
ode_system_random = list_all_ODEs_random(g, beta1, beta2, mu, p1_est, p2_est)

# set the initial condition
p0 = np.zeros(M)
i_set0 = all_states.index(I0)
p0[i_set0] = 1.0 # all other states have prob 0 at time 0
# p0

# %%
# solve ode_system_random over time
t_span = (0.0, new_time_max)

# times t_i to evaluate in, get saved in sol.t
steps_eval = 202
t_eval = np.linspace(t_span[0], t_span[1], steps_eval)

def f_ode(t, p):
    return ode_system_random(t, p)

sol = solve_ivp(f_ode, 
                t_span, 
                p0, 
                t_eval=t_eval,
                method="LSODA")

# %%
# plot both the expected values of p_{k}(t) 
# and the Gillespie average curve
# on the same figure

expected_values = calculate_expected_values(sol)

plt.figure()
plt.scatter(sol.t, expected_values, s = 10, color="k", 
            label=r"Expected values $E[p_{k}(t)]$")
plt.plot(sol.t, expected_values, lw=2, color="k", label="Solution of KEs")
plt.plot(times, avg_curve, 'red', label="Gillespie average curve")

plt.axhline(y=int(0.75 * N), color='black', lw=2, alpha=0.4, linestyle='-')

plt.xlabel("Time")
plt.ylabel("Number of Infected")
plt.legend()
plt.grid(True)
plt.title(f"H = {g.name}, N = {N}, k_threshold = {k_threshold}, trajectories = {len(X_sims_aligned)}")
plt.savefig(f"../figures/estimation/{test_name}/solution-vs-gillepsie_SC.pdf", 
            format='pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Calculate the estimates

# %%
## --- Calculate the estimates ---
min_Tk_threshold = 1e-6
estimates = calculate_estimates(X_sims_aligned, N, min_Tk_threshold)
# Out:
# Total events processed: 801010

# %%
a_k_hat = estimates["a_k_hat"]
b_k_hat = estimates["b_k_hat"]
c_k_hat = estimates["c_k_hat"]

# plot only where T_k was non-zero!
valid_k_idx = estimates["T_k"] > min_Tk_threshold   

# and compare them to theoretical rates
k_values = np.arange(0, N + 1) # number of infected from 0 to N
k_choose_2 = np.array(list(map(lambda k: comb(k, 2, exact=True), k_values)))

# TODO: what are theoretical rates now?
a_k = p1_est * beta1 * k_values * (N - k_values)
b_k = p2_est * beta2 * k_choose_2 * (N - k_values)
c_k = mu * k_values

fig = plt.figure()
ax = plt.subplot()

# theoretical ak vs. ak hats 
ax.plot(k_values, a_k, label=r'$a_k$', color="red")
ax.scatter(k_values[valid_k_idx], a_k_hat[valid_k_idx],
        label=r'$\widehat{a}_k$', color="black", alpha=0.9)
plt.xlabel("Number of Infected")
plt.ylabel("Rates and Counts")
plt.legend()
plt.grid(True)    
plt.savefig(f"../figures/estimation/{test_name}/estimates_ak_SC.pdf", 
            format='pdf', bbox_inches='tight')    
plt.show()

# theoretical bk vs. bk hats
fig = plt.figure()
ax = plt.subplot()
ax.plot(k_values, b_k, label=r'$b_k$', color="blue")
ax.scatter(k_values[valid_k_idx], b_k_hat[valid_k_idx],
        label=r'$\widehat{b}_k$', color="black", alpha=0.9)
plt.xlabel("Number of Infected")
plt.ylabel("Rates and Estimates")
plt.legend()
plt.grid(True)    
plt.savefig(f"../figures/estimation/{test_name}/estimates_bk_SC.pdf", 
            format='pdf', bbox_inches='tight')
plt.show()

# theoretical ck vs. ck hats (as a test only)
fig = plt.figure()
ax = plt.subplot()
ax.plot(k_values, c_k, label=r'$c_k$', color="green")
ax.scatter(k_values[valid_k_idx], c_k_hat[valid_k_idx],
        label=r'$\widehat{c}_k$', color="black", alpha=0.9)
plt.xlabel("Number of Infected")
plt.ylabel("Rates and Estimates")
plt.legend()
plt.grid(True)
plt.savefig(f"../figures/estimation/{test_name}/estimates_ck_SC.pdf", 
            format='pdf', bbox_inches='tight')    
plt.show()

# %% [markdown]
# ## Solve KEs using the estimates

# %%
## --- Solve KEs using the estimates and compare ---
# --- Model 2 ---
ode_system_complete = list_all_ODEs_using_estimates(g, a_k_hat, b_k_hat, mu)

def f_ode(t, p):
    return ode_system_complete(t, p)


all_states = list(range(N + 1))
M = len(all_states)
I0 = 100
p0 = np.zeros(M)
i_set0 = all_states.index(I0)
p0[i_set0] = 1.0 # all other states have prob 0 at time 0

sol_hat = solve_ivp(f_ode, 
                    t_span, 
                    p0, 
                    t_eval=t_eval,
                    method="LSODA")

expected_values_hat = calculate_expected_values(sol_hat)

# %%
plt.figure()

# plt.plot(sol.t, expected_values_hat, color="b", label="Model 2: Solution of KEs with ak_hats, bk_hats")
plt.scatter(sol.t, expected_values_hat, color="b", s=10, alpha=.8, label="Model 2: Solution of KEs with ak_hats, bk_hats")

plt.plot(times, avg_curve, 'red', label="Gillespie average curve", alpha=0.9)

plt.axhline(y=int(0.75 * N), color='black', lw=2, alpha=0.4, linestyle='-')

plt.xlabel("Time")
plt.ylabel("Number of Infected")
plt.legend()
plt.grid(True)
plt.title(f"H = {g.name}, N = {N}, k_threshold = {k_threshold}, trajectories = {len(X_sims_aligned)}")
plt.savefig(f"../figures/estimation/{test_name}/solutions-comparison_SC.pdf", 
            format='pdf', bbox_inches='tight')
plt.show()
