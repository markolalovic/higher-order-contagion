# %% [markdown]
# # Hypergraph Generators Test

# %%
import sys
sys.path.append('../src/')
sys.path.append('../scripts/')

from Hypergraphs import EmptyHypergraph
# from utils import draw_hypergraph

import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# ## E-R Hypergraphs

# %%
from generators_hg import test_ER_hypergraph

# %%
test_ER_hypergraph(test_p1_p2=False, test_k1_k2=False)
# Out:
# Using (k1, k2) = (10, 3)
# g_edges: [(0, 35), (0, 151), (0, 420), (0, 940), (1, 124)], ..., [(244, 581, 909), (162, 327, 401), (302, 936, 992), (36, 103, 666), (563, 804, 965)]
# p1 = 0.0100
# p2 = 0.00000602

# %% [markdown]
# $p_1 = 0.01 > ln(N)/N \approx 0.0069 \text{ where } E[\text{isolated nodes}] \approx 1$
#
# $G$ is connected almost surely..

# %%
# test_ER_hypergraph(test_p1_p2=True)

# %%
# test_ER_hypergraph(test_k1_k2=True)

# %% [markdown]
# <!-- ## NegBinom Hypergraph -->

# %%
# from generators_hg import test_neg_binom_hypergraph
# test_neg_binom_hypergraph()

# %% [markdown]
# ## ScaleFree Hypergraphs

# %%
from generators_hg import test_scale_free_hypergraph

# %%
test_scale_free_hypergraph()
# Out:
# 	ScaleFree on 2000 nodes with 4325 edges.
#
# Figure saved to: ../figures/hypergraphs/scale_free_hypergraph_degree_distributions.pdf

# %% [markdown]
# ## Regular Hypergraphs

# %%
# TODO
