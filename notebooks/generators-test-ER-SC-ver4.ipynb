# %% [markdown]
# #  Erdos-Renyi SC test - Version 4

# %%
import sys
sys.path.append('../src/')

from higher_order_structures import ErdosRenyiSC
from plot_utils import plot_degree_distribution_ErdosRenyiSC

# %%
# test ER SC version 4
N = 1000
d1, d2 = (20, 6)
g = ErdosRenyiSC(N, d1, d2)

# %%
g.print()
# Out:
# 	Erdos-Renyi-SC on 1000 nodes with 11959 edges.

# %%
print(f"{g.p1_realized:.8f}, {g.p2_realized:.8f}")
# Out:
# 0.01997397, 0.00001193

# %%
g.summary()
# Out:
# --------------------------------------
# 	Target d1: 20.00, Realized d1: 19.95
# 	Target d2: 6.00, Realized d2: 5.95
#
# 	Initial p_G used for G(N, p_G): 0.00817743
#
# 	Expected p1: 0.02002002
# 	Expected p2: 0.00001204
#
# 	Target p1:  0.02002002
# 	Target p2:  0.00001204
#
# --------------------------------------
# 	Realized p1: 0.01997397
# 	Realized p2: 0.00001193
#
# 	Realized number of pw edges:  9977/499500
# 	Realized number of ho edges:  1982/166167000

# %% [markdown]
# # Degree distribution

# %%
plot_degree_distribution_ErdosRenyiSC(g)
