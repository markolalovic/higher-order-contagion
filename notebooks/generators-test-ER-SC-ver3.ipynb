# %% [markdown]
# #  Erdos-Renyi SC test

# %%
import sys
sys.path.append('../src/')

from higher_order_structures import ErdosRenyiSC
from plot_utils import plot_degree_distribution_ErdosRenyiSC

# %%
# test ER SC version 2
N = 1000
d1, d2 = (20, 6)

g = ErdosRenyiSC(N, d1, d2)

# %%
g.print()
# Out:
# 	Erdos-Renyi-SC on 1000 nodes with 11942 edges.

# %%
g.summary()
# Out:
# 	Target d1: 20.00, Realized d1: 19.89
# 	Target d2: 6.00, Realized d2: 5.99
#
# 	Initial p1 used for G(N, p1): 0.0081
# 	Expected p1 used for pw edges: 0.01994882
# 	Expected p2 used for ho edges: 0.00001204
#
# 	Realized p1_overall: 0.0199
# 	Realized p2: 0.00001201
#
# 	Realized pw edges:  9946/499500
# 	Realized ho edges:  1996/166167000

# %% [markdown]
# # Degree distribution

# %%
plot_degree_distribution_ErdosRenyiSC(g)
